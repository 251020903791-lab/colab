# %% [markdown]
# <a href="https://colab.research.google.com/github/251020903791-lab/colab/blob/main/vandeptrai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hall =11
kit = 14
bed = 20
bath = 23
house = [ ["hallway", hall], ["kitchen", kit], ["living room", bath], "bedroom", bed]
print(house)
print(type(house))
# Out:
# [['hallway', 11], ['kitchen', 14], ['living room', 23], 'bedroom', 20]
# <class 'list'>

# %% [markdown]
# # Mục mới

# %%
areas = ["hallway", 11, "kitchen", 14, "living room ",20, "bedroom", 23]
print(areas[1])
dowstairs = areas[0:6]
upstairs = areas [6:-1]
print(dowstairs)
print(upstairs)
# Out:
# 11
# ['hallway', 11, 'kitchen', 14, 'living room ', 20]
# ['bedroom']
