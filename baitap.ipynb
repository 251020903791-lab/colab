# %% [markdown]
# <a href="https://colab.research.google.com/github/251020903791-lab/colab/blob/main/baitap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Nhập số nguyên dương n:"))
tong = 0
so_chan = 0
if n <= 0 :
  print("Vui lòng nhấp lại số nguyên dương!")
else :
  while so_chan < n :
    tong += so_chan
    so_chan += 2
    print("Tổng các số chẵn nhỏ hơn {n} là {tong}")

# %%
n = int(input("Nhấp số nguyên dương n :"))
tong =0
if n <= 0 :
  print("Vui lòng nhập số nguyên dương!")
else :

    for i in range (n+1):
      tong += i
print(f"Tổng các số từ 0 đến {n} là :{tong}")

# %%
a = float(input("Nhập hệ số a:"))
b = float(input("Nhập hệ số b:"))
c = float(input('Nhập hệ số c:'))

if a == 0:
  print("a = 0, phương trình trở thành hệ phương trình bậc nhất hoặc không hợp lệ.")
  if b == 0:
    if c == 0:
      print("phương trình có vô số nghiệm")
    else:
      print("phương trình vô nghiệm")
  else:
    x = -c / b
    print(f"phương trình có nghiệm duy nhất: x = {x}")
else:
  delta = b**2 - 4*a*c
  print(f"Delta = {delta}")
  if delta > 0:
    x1 = ((-b + delta**0.5) / (2*a))
    x2 = ((-b - delta**0.5) / (2*a))
    print(f"phương trình có 2 nghiệm phân biệt : x1 = {x1}, x2 = {x2} ")
  elif delta == 0:
    x = -b / (2*a)
    print(f"phương trình có nghiệm kép : x = {x}")
  else:
    # delta < 0 is implied here
    print("phương trình vô nghiệm trong tập số thực")
